# %% [markdown]
# ## basics of opencv

# %%
from matplotlib import pyplot as plt

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.10.0

# %%
img=cv2.imread(r"C:\\Users\\KIIT\\Desktop\\Age_and_gender_detector\\Resources\\IMG_0013.jpg")

# %%
plt.imshow(img)

# %%
import cv2

img = cv2.imread(r"C:\\Users\\KIIT\\Desktop\\Age_and_gender_detector\\Resources\\IMG__0010.jpg")

if img is None:
    print("Error: Image not read properly. Check the file path and the file itself.")
else:
    print("Image read successfully.")
# Out:
# Error: Image not read properly. Check the file path and the file itself.

# %% [markdown]
# #Arithemetic operations

# %%
img1=cv2.imread(r"C:\\Users\\KIIT\\Desktop\\Age_and_gender_detector\\Resources\\IMG_0013.jpg")
plt.imshow(img1)

# %%
img2=cv2.imread(r"C:\\Users\\KIIT\\Desktop\\Age_and_gender_detector\\Resources\\IMG_0014.jpg")
plt.imshow(img2)

# %%
res = img1+ img2

# %%
plt.imshow(res)

# %%
res1 = img1 -img2

# %%
plt.imshow(res1)

# %%
res2 = img1*img2

# %%
plt.imshow(res2)

# %%
res3=img1/img2
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_23000\3923951289.py:1: RuntimeWarning: divide by zero encountered in divide
#   res3=img1/img2

# %%
plt.imshow(res3)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.1606425702811245..255.0].

# %%
img=cv2.imread(r"C:\\Users\\KIIT\\Desktop\\Age_and_gender_detector\\Resources\\IMG_0013.jpg")
